# %%
# K-Means Clustering

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values
# y = dataset.iloc[:, 3].values

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
#end of lib

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
atrA = SS.fit_transform(X[:,[0]])
atrB = SS.fit_transform(X[:,[1]])
#normalisasi Z-Score
# print(atrA)
# print(atrB)

# %%
datanya = []
for i in range (len(atrA)):
    datanya.append([float(atrA[i]),float(atrB[i])])
# datanya

# %%
import random
#generate centroid
randnum = random.sample(range(len(datanya)), 5)
centroid = []
for i in range(len(randnum)):
    centroid.append(datanya[randnum[i]])
# centroid

# %%
#manhattan distance
stat = True
while (stat):
    cluster0 = []
    cluster1 = []
    cluster2 = []
    cluster3 = []
    cluster4 = []
    for i in range(len(datanya)):
        jarak = []
        newcentroid = []
        for j in range(5):
            jarak.append(abs(datanya[i][0]-centroid[j][0]) + abs(datanya[i][1]-centroid[j][1]))
        if jarak.index(min(jarak)) == 0:
            cluster0.append(datanya[i])
        if jarak.index(min(jarak)) == 1:
            cluster1.append(datanya[i])
        if jarak.index(min(jarak)) == 2:
            cluster2.append(datanya[i])
        if jarak.index(min(jarak)) == 3:
            cluster3.append(datanya[i])
        if jarak.index(min(jarak)) == 4:
            cluster4.append(datanya[i])
#     print(jarak)
    #cent1
    totalx = 0
    totaly = 0
#     print(len(cluster0))
    for i in range(len(cluster0)):
        totalx = totalx + cluster0[i][0]
        totaly = totaly + cluster0[i][1]
#     print(totalx)
    newcentroid.append([totalx/len(cluster0),totaly/len(cluster0)])
    #cent2
    totalx = 0
    totaly = 0
    for i in range(len(cluster1)):
        totalx = totalx + cluster1[i][0]
        totaly = totaly + cluster1[i][1]
    newcentroid.append([totalx/len(cluster1),totaly/len(cluster1)])

    #cent3
    totalx = 0
    totaly = 0
    for i in range(len(cluster2)):
        totalx = totalx + cluster2[i][0]
        totaly = totaly + cluster2[i][1]
    newcentroid.append([totalx/len(cluster2),totaly/len(cluster2)])

    #cent4
    totalx = 0
    totaly = 0
    for i in range(len(cluster3)):
        totalx = totalx + cluster3[i][0]
        totaly = totaly + cluster3[i][1]
    newcentroid.append([totalx/len(cluster3),totaly/len(cluster3)])

    #cent5
    totalx = 0
    totaly = 0
    for i in range(len(cluster4)):
        totalx = totalx + cluster4[i][0]
        totaly = totaly + cluster4[i][1]
    newcentroid.append([totalx/len(cluster4),totaly/len(cluster4)])
    if centroid == newcentroid:
        stat = False
    else:
        centroid = []
        centroid = newcentroid.copy()
#     print(len(cluster0),len(cluster1),len(cluster2),len(cluster3),len(cluster4))
#     print("lel",newcentroid)

# %%
c0x = []
c0y = []
for i in range(len(cluster0)):
    c0x.append(cluster0[i][0])
    c0y.append(cluster0[i][1])
c1x = []
c1y = []
for i in range(len(cluster1)):
    c1x.append(cluster1[i][0])
    c1y.append(cluster1[i][1])
c2x = []
c2y = []
for i in range(len(cluster2)):
    c2x.append(cluster2[i][0])
    c2y.append(cluster2[i][1])
c3x = []
c3y = []
for i in range(len(cluster3)):
    c3x.append(cluster3[i][0])
    c3y.append(cluster3[i][1])
c4x = []
c4y = []
for i in range(len(cluster4)):
    c4x.append(cluster4[i][0])
    c4y.append(cluster4[i][1])
ncx = []
ncy = []
for i in range(len(newcentroid)):
    ncx.append(newcentroid[i][0])
    ncy.append(newcentroid[i][1])
# print(len(c0x))
# print(len(c1x))
# print(len(c2x))
# print(len(c3x))
# print(len(c4x))

# %%
plt.scatter(c0x, c0y, s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(c1x, c1y, s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(c2x, c2y, s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(c3x, c3y, s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(c4x, c4y, s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(ncx, ncy, s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
