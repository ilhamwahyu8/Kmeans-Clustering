# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random as rd
# Importing the dataset
dataset = pd.read_csv('Mall_Customers.csv')
X = dataset.iloc[:, [3, 4]].values

# %%
#Non Normalisasi

# %%
atrA = X[:,[0]]
atrB = X[:,[1]]
datanya = []
for i in range (len(atrA)):
    datanya.append([float(atrA[i]),float(atrB[i])])

# %%
#generate centroid
randnum = rd.sample(range(len(datanya)), 5)
centroid = []
for i in range(len(randnum)):
    centroid.append(datanya[randnum[i]])

# %%
stat = True
while stat:
    clusters = []
    clustersidx = []
    for i in range(len(centroid)):
        clusters.append([])
        clustersidx.append([])
    for i in range(len(datanya)):
        jarak = []
        newCentroid = []
        for j in range(len(centroid)):
            hitungan = 0
            for k in range (2): 
#               nanti ubah
                hitungan += abs(datanya[i][k]-centroid[j][k])
            jarak.append(hitungan)
        minIdx = jarak.index(min(jarak))
#         for k in range (2): 
        clusters[minIdx].append(datanya[i])
        clustersidx[minIdx].append(i)
    newCentroid = []
    for i in range(len(centroid)):
        totalAtr0 = 0
        totalAtr1 = 0
        #atur sebanyak atr
        for j in range(len(clusters[i])):
            totalAtr0 += clusters[i][j][0]
            totalAtr1 += clusters[i][j][1]
        newCentroid.append([totalAtr0/len(clusters[i]),totalAtr1/len(clusters[i]) ]) 
    if centroid == newCentroid:
        stat = False
    else:
        centroid = []
        centroid = newCentroid.copy()

# %%
plotCX = []
plotCY = []
for i in range(len(newCentroid)):
    plotCX.append(newCentroid[i][0])
    plotCY.append(newCentroid[i][1])

# %%
plt.scatter(X[clustersidx[0],[0]], X[clustersidx[0],[1]], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[clustersidx[1],[0]], X[clustersidx[1],[1]], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[clustersidx[2],[0]], X[clustersidx[2],[1]], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[clustersidx[3],[0]], X[clustersidx[3],[1]], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[clustersidx[4],[0]], X[clustersidx[4],[1]], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(plotCX, plotCY, s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
#Normalisasi

# %%
from sklearn.preprocessing import MinMaxScaler
atrA = MinMaxScaler().fit_transform(X[:,[0]])
atrB = MinMaxScaler().fit_transform(X[:,[1]])
datanya = []
for i in range (len(atrA)):
    datanya.append([float(atrA[i]),float(atrB[i])])

# %%
#generate centroid
randnum = rd.sample(range(len(datanya)), 5)
centroid = []
for i in range(len(randnum)):
    centroid.append(datanya[randnum[i]])

# %%
stat = True
while stat:
    clusters = []
    clustersidx = []
    for i in range(len(centroid)):
        clusters.append([])
        clustersidx.append([])
    for i in range(len(datanya)):
        jarak = []
        newCentroid = []
        for j in range(len(centroid)):
            hitungan = 0
            for k in range (2): 
#               nanti ubah
                hitungan += abs(datanya[i][k]-centroid[j][k])
            jarak.append(hitungan)
        minIdx = jarak.index(min(jarak))
#         for k in range (2): 
        clusters[minIdx].append(datanya[i])
        clustersidx[minIdx].append(i)
    newCentroid = []
    for i in range(len(centroid)):
        totalAtr0 = 0
        totalAtr1 = 0
        #atur sebanyak atr
        for j in range(len(clusters[i])):
            totalAtr0 += clusters[i][j][0]
            totalAtr1 += clusters[i][j][1]
        newCentroid.append([totalAtr0/len(clusters[i]),totalAtr1/len(clusters[i]) ]) 
    if centroid == newCentroid:
        stat = False
    else:
        centroid = []
        centroid = newCentroid.copy()

# %%
# Normalisasi
plot0X = []
plot0Y = []
# for i in range(len(clusters)):
for i in range(len(clusters[0])):
    plot0X.append(clusters[0][i][0])
    plot0Y.append(clusters[0][i][1])
plot1X = []
plot1Y = []
# for i in range(len(clusters)):
for i in range(len(clusters[1])):
    plot1X.append(clusters[1][i][0])
    plot1Y.append(clusters[1][i][1])
plot2X = []
plot2Y = []
# for i in range(len(clusters)):
for i in range(len(clusters[2])):
    plot2X.append(clusters[2][i][0])
    plot2Y.append(clusters[2][i][1])
plot3X = []
plot3Y = []
# for i in range(len(clusters)):
for i in range(len(clusters[3])):
    plot3X.append(clusters[3][i][0])
    plot3Y.append(clusters[3][i][1])
plot4X = []
plot4Y = []
# for i in range(len(clusters)):
for i in range(len(clusters[4])):
    plot4X.append(clusters[4][i][0])
    plot4Y.append(clusters[4][i][1])
plotCX = []
plotCY = []
for i in range(len(newCentroid)):
    plotCX.append(newCentroid[i][0])
    plotCY.append(newCentroid[i][1])

# %%
plt.scatter(plot0X, plot0Y, s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(plot1X, plot1Y, s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(plot2X, plot2Y, s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(plot3X, plot3Y, s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(plot4X, plot4Y, s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(plotCX, plotCY, s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (Scaled 0-1)')
plt.ylabel('Spending Score (Scaled 0-1)')
plt.legend()
plt.show()
